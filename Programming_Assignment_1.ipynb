# %%
#1. Write a Python program to print "Hello Python"?
#2. Write a Python program to do arithmetical operations addition and division.?
#3. Write a Python program to find the area of a triangle?
#4. Write a Python program to swap two variables?
#5. Write a Python program to generate a random number?

# %%
#1. Write a Python program to print "Hello Python"?
print("Hello Python")
# Out:
# Hello Python

# %%
#2. Write a Python program to do arithmetical operations addition and division.?
num1 = int(input("Enter a number1: "))
num2 = int(input("Enter a number2: "))
print(f"this is the sum of given two numbers: {num1 + num2}")
# Out:
# Enter a number1:  1
# Enter a number2:  2
# this is the sum of given two numbers: 3

# %%
#3. Write a Python program to find the area of a triangle?
# formula of the tringle area is base*hight/2
BaseOfTringle = 3
HeightOfTringle = 4
print(f"AreaOfTheTringle: {.5*BaseOfTringle*HeightOfTringle}")
# Out:
# AreaOfTheTringle: 6.0

# %%
#4. Write a Python program to swap two variables? using temvariable
a = 2
b = 3
t = a
a = b
b = t
print("a: ",a)
print("b: ",b)
# Out:
# a:  3
# b:  2

# %%
#5. Write a Python program to generate a random number? 
import random
num = random.randint(1,100)
print(f"Random number: {num}")
# Out:
# Random number: 92
